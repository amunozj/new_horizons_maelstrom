# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
shipsdDf = pd.read_csv('../ship_init_COAS.csv', index_col=0)
shipsdDf
# Out:
#                Name  Class  Weight  Capacity CannonsQuantity  Track1.ZStart  \
# 0           Tartane      7      10        65               0           0.20
# 1      BarcoCostero      7      10        75               0           0.20
# 2      ArmedTartane      7      20       175               6           0.20
# 3        TartaneWar      7      20       175               8           0.20
# 4        WarTartane      7      35       420               4           0.20
# ..              ...    ...     ...       ...             ...            ...
# 214          BrigSW      4     200      2500              24           0.20
# 215        XebekVML      4     350      2000              22           0.20
# 216  Corvette_quest      3     400      4000              40           0.17
# 217    ArabellaShip      2    1200      5400              52           0.20
# 218  Flyingdutchman      1    2500      6800              60           0.25
#
# ...

# %%
for key in shipsdDf.keys()[5:-1]:
    fig, ax = plt.subplots()
    ax.scatter(shipsdDf['Class'], shipsdDf[key])
    ax.set_xlabel('Class')
    ax.set_ylabel(key)

# %%
for key in shipsdDf.keys()[5:-1]:
    fig, ax = plt.subplots()
    ax.scatter(shipsdDf['Weight'], shipsdDf[key])
    ax.set_xlabel('Weight')
    ax.set_ylabel(key)

# %%
for key in shipsdDf.keys()[5:-1]:
    fig, ax = plt.subplots()
    ax.scatter(shipsdDf['Capacity'], shipsdDf[key])
    ax.set_xlabel('Capacity')
    ax.set_ylabel(key)
